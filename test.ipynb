# %%
import scipy.io
mat = scipy.io.loadmat('emotion_data/Dreamer/DREAMER.mat')

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'DREAMER'])

# %%
# mat['DREAMER'][0][0][0][0][0][0][0]
# len(mat['DREAMER'][0][0][0][0])
len(mat['DREAMER'][0])
# mat['DREAMER'][0][0][0][1]
# mat.keys()
# Out:
# 1

# %%
d = mat['DREAMER']
len(d[0][0])
# Out:
# 10

# %%
dd = d[0][0]
# len(dd[3])
ddd = dd[0]
data = ddd[0]

# %%
# len(ddd[0][0][0][0])
# type(ddd)
subj = data[0][0]

# %%
# subj
# data[0][0]
# len(subj[0])
subj[0][1]
# Out:
# array(['male'], dtype='<U4')
